# %% [markdown]
# # vctk

# %%
# test_dict = {'p225':'female',
#              'p226':'male',
#              'p227':'male',
#              'p228':'female',
#              'p229':'female',
#              'p230':'female',
#              'p232':'male',
#              'p236':'female',
#              'p237':'male',
#              'p241':'male'}
# test_id = ['p225','p226', 'p227', 'p228', 'p229', 'p230', 'p232', 'p236', 'p237', 'p241']
test_dict = {'p334':'male',
             'p343':'female',
             'p360':'male',
             'p362':'female',
             'p252':'male',
             'p261':'female',
             'p232':'male',
             'p228':'female',
             'p237':'male',
             'p225':'female'
             }
test_id = ['p334', 'p343', 'p360', 'p362', 'p252', 'p261', 'p232', 'p228', 'p237', 'p225']

# %%
path = '/Netdata/yangyg/dataset/cmu_data/vctk/audio/'

import IPython
import numpy as np
import soundfile

name = 'audio-p230_002.npy'
wav = np.load(path+name)
IPython.display.Audio(wav, rate = 16000)

soundfile.write('./'+name.replace('.npy','.wav'), wav, 16000)

# %% [markdown]
# # Hisense

# %%
path = '/Netdata/shiyao/RAWDATA/HISENSE/RAW_DATA/WPE_data/'

import IPython
import numpy as np
import soundfile as sf

name = 'HSE00030009.wav'
sig, sample_rate = sf.read(path+name)
IPython.display.Audio(sig, rate = sample_rate)

# soundfile.write('./'+name.replace('.npy','.wav'), sig, 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # ssb

# %%
import IPython
import numpy as np
import soundfile as sf

name = 'SSB14570005.wav'
path = '/NASdata/AudioData/AISHELL-ASR-SSB/data_16k/wav/{}/'.format(name[:7])

sig, sample_rate = sf.read(path+name)
IPython.display.Audio(sig, rate = sample_rate)

sf.write('./'+name.replace('.npy','.wav'), sig, 16000)

# %% [markdown]
# # taiwan

# %%
path = '/NASdata/AudioData/mandarin/speech_synthesis/taiwan/'
import IPython
import numpy as np
import soundfile as sf

name = 'TW60272.wav'
sig, sample_rate = sf.read(path+name)
IPython.display.Audio(sig, rate = sample_rate)
sf.write('./'+name.replace('.npy','.wav'), sig, 16000)

# %%
path = '/NASdata/AudioData/mandarin/speech_synthesis/male_for_arrest-record/answers/16k_mono_vad/'
import IPython
import numpy as np
import soundfile as sf

name = 'an_1-1058.wav'
sig, sample_rate = sf.read(path+name)
IPython.display.Audio(sig, rate = sample_rate)
sf.write('./'+name.replace('.npy','.wav'), sig, 16000)

# %%
path = '/NASdata/AudioData/mandarin/speech_synthesis/blizzard2019/wave16k/'
import IPython
import numpy as np
import soundfile as sf

name = '100006.wav'
sig, sample_rate = sf.read(path+name)
IPython.display.Audio(sig, rate = sample_rate)
sf.write('./'+name.replace('.npy','.wav'), sig, 16000)

# %%
path = '/mingback/caizexin/vcc2018/experiments/elo5h_dn/EL5h_test_cvf0_gmm_ppp2tf0/116939_cvf0_gmm_ppp2tf0.wav'
import IPython
import numpy as np
import soundfile as sf

# name = '100006.wav'
sig, sample_rate = sf.read(path)
# sig = np.load(path)
IPython.display.Audio(sig, rate = 16000)
# sf.write('./'+name.replace('.npy','.wav'), sig, 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
path = '/mingback/caizexin/vcc2018/sprocket/example/data/wav/EL5h_dn_src_webrtc/114039.wav'
import IPython
import numpy as np
import soundfile as sf

# name = '100006.wav'
sig, sample_rate = sf.read(path)
# sig = np.load(path)
IPython.display.Audio(sig, rate = 16000)
# sf.write('./'+name.replace('.npy','.wav'), sig, 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
